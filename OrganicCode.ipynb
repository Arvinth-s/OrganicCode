# %%
#OM NAMO NARAYANA

# %%
group = []
group.append(["H", "Li", "Na", "K", "Rb", "Cs", "Fr"])
group.append("Be Mg Ca Ba Sr Ba Ra".split())
group.append("B Al Ga In Tl".split())
group.append("C Si Ge Tn Pb".split())
group.append("N P As Sb Bi".split())
group.append("O S Se Te Po".split())
group.append("F Cl Br I At".split())
group.append("He Ne Ar Kr Xe Rn".split())

# %%
group[0]
# Out:
# ['H', 'Li', 'Na', 'K', 'Rb', 'Cs', 'Fr']

# %%
group[1]
# Out:
# ['Be', 'Mg', 'Ca', 'Ba', 'Sr', 'Ba', 'Ra']

# %%
def encode(ele):
    ngroup = 0
    count = 1
    ele = ele+' '
    code = 1
    if(ele[1] < 'a' or ele[1] > 'z'):
        count += 1 
    for i in range(len(group)):
        if(ele[:-count] in group[i]):
            temp = group[i].index(ele[:-count])
            code = code*1000*(i+1) + code*100*(temp)+int(ele[count-1:len(ele)-1])
            print(code)
            break
    return code

# %%
def decode(code):
    decoded = str(group[int(code/pow(10, len(str(code)) - 1))- 1][int(str(code)[1])])+str(int(str(code)[len(str(code)) - 1]))
    return decoded

# %%
decode(encode("C2"))
# Out:
# 4002
# 'C2'

# %%
import jgraph
from time import sleep

color = []
color.append(0xff)#blue
color.append(0xffaa)#light green
color.append(0x000000)#black
color.append(0x868686)#gray
color.append(0xffaaaa)#pink
color.append(0xB61AB3)#violet
color.append(0xfffaaa)#yellow
color.append(0x000000)#black
color.append(0xff)#blue
color.append(0xff0000)#red

graph = []
graph.append({
    'nodes':{
        },
    'edges':[
        ]
    })
count = 1
_s = []
#THIS IS THE FILE LOCATION OF YOUR SOURCE
with open("D:\spider\OrganicCode\OrganicData.txt") as file:
    _s.append(file.read())
lines = []

for line in _s[0].split('\n'):
    lines.append(line)
    #print(line)
end = 0
count_line  = 0
count_stack = 0
while(end == 0):
    count_stack = count_line
    #print("count_stack", count_stack)

    for line in lines[count_stack:]:
        count_line += 1
        #print("line", line)
        if(len(line)== 0):
            count += 1
            print("index", count)
            #print("graph", graph[count-2])
            jgraph.draw(graph[count-2], directed = False)
            break
        bond = line.split()
        atom = int(bond[0].split('|')[0])
        charge = int(bond[0].split('|')[1])

        if(int(atom/1000) == 1):
            size = 1
            scolor = color[1]
        else:
            size = 2 - (atom/1000)/8 + int((atom/100)%10)/4
            scolor = color[int(atom/1000)]
        if(charge == 11):
            scolor = color[8]
        elif(charge == 9):
            scolor = color[9]
        graph[count-1]['nodes'][decode(atom)] = {'size':2 + size/2, 'color': scolor}
        for edge in bond[1:-1]:
            _edge = edge.split('|')
            edge = int(_edge[0])
            mbond = int(_edge[1])
            bond_color = color[mbond]
            dic = {'source':decode(atom), 'target':decode(edge), 'size':3*mbond, 'color':bond_color}
            graph[count-1]['edges'].append(dic)
    graph.append({
    'nodes':{
        },
    'edges':[
        ]
    })       
    end = int(bond[len(bond)-1][1])
    #jgraph.draw(graph, directed = False)
# Out:
# index 2
# <div id="graph-effd0d3a-26cd-41a6-bc8c-9a04cb35bc84"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-effd0d3a-26cd-41a6-bc8c-9a04cb35bc84');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
# ...

# %%
graph = {'nodes': {'C1': {'size': 2.7499374999999997, 'color': 16755370}, 
                   'C2': {'size': 2.7498750000000003, 'color': 16755370}, 
                   'C3': {'size': 2.7498125, 'color': 16755370}, 
                   'C4': {'size': 2.74975, 'color': 16755370},
                   'C5': {'size': 2.7496875000000003, 'color': 16755370}, 
                   'C6': {'size': 2.749625, 'color': 16755370}, 
                   'H1': {'size': 2.5, 'color': 65450}, 
                   'H2': {'size': 2.5, 'color': 65450}, 
                   'H3': {'size': 2.5, 'color': 65450}, 
                   'H4': {'size': 2.5, 'color': 65450}, 
                   'H5': {'size': 2.5, 'color': 65450}, 
                   'H6': {'size': 2.5, 'color': 65450}}, 
         'edges': [{'source': 'C1', 'target': 'C2', 'size': 3, 'color': 65450}, 
                   {'source': 'C1', 'target': 'C6', 'size': 3, 'color': 65450}, 
                   {'source': 'C1', 'target': 'H1', 'size': 3, 'color': 65450}, 
                   {'source': 'C2', 'target': 'C1', 'size': 3, 'color': 65450}, 
                   {'source': 'C2', 'target': 'C3', 'size': 6, 'color': 0}, 
                   {'source': 'C2', 'target': 'H2', 'size': 3, 'color': 65450}, 
                   {'source': 'C3', 'target': 'C4', 'size': 3, 'color': 65450}, 
                   {'source': 'C3', 'target': 'C2', 'size': 6, 'color': 0}, 
                   {'source': 'C3', 'target': 'H3', 'size': 3, 'color': 65450}, 
                   {'source': 'C4', 'target': 'C3', 'size': 3, 'color': 65450}, 
                   {'source': 'C4', 'target': 'C5', 'size': 3, 'color': 65450}, 
                   {'source': 'C4', 'target': 'H4', 'size': 3, 'color': 65450}, 
                   {'source': 'C5', 'target': 'C6', 'size': 6, 'color': 0}, 
                   {'source': 'C5', 'target': 'C4', 'size': 3, 'color': 65450},
                   {'source': 'C5', 'target': 'H5', 'size': 3, 'color': 65450}, 
                   {'source': 'C6', 'target': 'C5', 'size': 6, 'color': 0}, 
                   {'source': 'C6', 'target': 'C1', 'size': 3, 'color': 65450}, 
                   {'source': 'C6', 'target': 'H6', 'size': 3, 'color': 65450}, 
                   {'source': 'H1', 'target': 'C1', 'size': 3, 'color': 65450}, 
                   {'source': 'H2', 'target': 'C2', 'size': 3, 'color': 65450}, 
                   {'source': 'H3', 'target': 'C3', 'size': 3, 'color': 65450}, 
                   {'source': 'H4', 'target': 'C4', 'size': 3, 'color': 65450}, 
                   {'source': 'H5', 'target': 'C5', 'size': 3, 'color': 65450}, 
                   {'source': 'H6', 'target': 'C6', 'size': 3, 'color': 65450}]}
jgraph.draw(graph)
# Out:
# <div id="graph-bb66ff44-d7e8-4275-94c2-00f2b251e745"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-bb66ff44-d7e8-4275-94c2-00f2b251e745');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
# ...

# %%
graph =  {'nodes': {'C1': {'size': 2.7499374999999997, 'color': 16755370}, 
                 'C2': {'size': 2.7498750000000003, 'color': 16755370}, 
                 'C3': {'size': 2.7498125, 'color': 16755370}, 
                 'C4': {'size': 2.74975, 'color': 16755370}, 
                 'C5': {'size': 2.7496875000000003, 'color': 16755370}, 
                 'C6': {'size': 2.749625, 'color': 16755370}, 
                 'H1': {'size': 2.5, 'color': 65450}, 
                 'H2': {'size': 2.5, 'color': 65450}, 
                 'H3': {'size': 2.5, 'color': 65450}, 
                 'H4': {'size': 2.5, 'color': 65450}, 
                 'H5': {'size': 2.5, 'color': 65450}, 
                 'H6': {'size': 2.5, 'color': 65450}}, 
       'edges': [{'source': 'C1', 'target': 'C2', 'size': 6, 'color': 0}, 
                 {'source': 'C1', 'target': 'C6', 'size': 3, 'color': 65450}, 
                 {'source': 'C1', 'target': 'H1', 'size': 3, 'color': 65450}, 
                 {'source': 'C2', 'target': 'C1', 'size': 6, 'color': 0}, 
                 {'source': 'C2', 'target': 'C3', 'size': 3, 'color': 65450}, 
                 {'source': 'C2', 'target': 'H2', 'size': 3, 'color': 65450}, 
                 {'source': 'C3', 'target': 'C4', 'size': 6, 'color': 0},
                 {'source': 'C3', 'target': 'C2', 'size': 3, 'color': 65450}, 
                 {'source': 'C3', 'target': 'H3', 'size': 3, 'color': 65450}, 
                 {'source': 'C4', 'target': 'C3', 'size': 6, 'color': 0}, 
                 {'source': 'C4', 'target': 'C5', 'size': 3, 'color': 65450}, 
                 {'source': 'C4', 'target': 'H4', 'size': 3, 'color': 65450}, 
                 {'source': 'C5', 'target': 'C6', 'size': 6, 'color': 0}, 
                 {'source': 'C5', 'target': 'C4', 'size': 3, 'color': 65450}, 
                 {'source': 'C5', 'target': 'H5', 'size': 3, 'color': 65450}, 
                 {'source': 'C6', 'target': 'C5', 'size': 6, 'color': 0}, 
                 {'source': 'C6', 'target': 'C1', 'size': 3, 'color': 65450}, 
                 {'source': 'C6', 'target': 'H6', 'size': 3, 'color': 65450}, 
                 {'source': 'H1', 'target': 'C1', 'size': 3, 'color': 65450}, 
                 {'source': 'H2', 'target': 'C2', 'size': 3, 'color': 65450}, 
                 {'source': 'H3', 'target': 'C3', 'size': 3, 'color': 65450}, 
                 {'source': 'H4', 'target': 'C4', 'size': 3, 'color': 65450}, 
                 {'source': 'H5', 'target': 'C5', 'size': 3, 'color': 65450}, 
                 {'source': 'H6', 'target': 'C6', 'size': 3, 'color': 65450}]}
jgraph.draw(graph)
# Out:
# <div id="graph-17f68a9b-b915-46b0-9a7e-26b42d347a75"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-17f68a9b-b915-46b0-9a7e-26b42d347a75');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x5bc0de',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'basic',
#                                      z: 100,
#                                      runOptimization: true,
# ...
